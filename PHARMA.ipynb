# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrasekhark/PythonforDataScience/blob/main/PHARMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn import preprocessing

from sklearn.metrics import accuracy_score

def warn(*args, **kwargs): pass
import warnings
warnings.warn = warn

# %%
df_train = pd.read_csv(r'/content/train.csv')
df_test = pd.read_csv(r'/content/test.csv')

# %%
import sys

print ('Total Number of arguments:', len(sys.argv), 'arguments.')
print ('Argument List:', str(sys.argv))
print (sys.argv[0])
# Out:
# Total Number of arguments: 3 arguments.
# Argument List: ['/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-1482d487-4ebe-42cd-8d1d-452beeee32a1.json']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py

# %%
df_train.head()
# Out:
#    id                species   margin1  ...  texture62  texture63  texture64
# 0   1            Acer_Opalus  0.007812  ...   0.004883   0.000000   0.025391
# 1   2  Pterocarya_Stenoptera  0.005859  ...   0.000977   0.039062   0.022461
# 2   3   Quercus_Hartwissiana  0.005859  ...   0.000000   0.020508   0.002930
# 3   5        Tilia_Tomentosa  0.000000  ...   0.017578   0.000000   0.047852
# 4   6     Quercus_Variabilis  0.005859  ...   0.000000   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
df_test.head()
# Out:
#    id   margin1   margin2   margin3  ...  texture61  texture62  texture63  texture64
# 0   4  0.019531  0.009766  0.078125  ...        0.0   0.000000   0.003906   0.053711
# 1   7  0.007812  0.005859  0.064453  ...        0.0   0.000977   0.037109   0.044922
# 2   9  0.000000  0.000000  0.001953  ...        0.0   0.015625   0.000000   0.000000
# 3  12  0.000000  0.000000  0.009766  ...        0.0   0.089844   0.000000   0.008789
# 4  13  0.001953  0.000000  0.015625  ...        0.0   0.007812   0.009766   0.007812
#
# [5 rows x 193 columns]

# %% [markdown]
# # **Data Preparation**

# %%
df_train.shape
# Out:
# (990, 194)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Columns: 194 entries, id to texture64
# dtypes: float64(192), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
df_train.isna().sum()
# Out:
# id           0
# species      0
# margin1      0
# margin2      0
# margin3      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 194, dtype: int64

# %%
df_train.nunique()
# Out:
# id           990
# species       99
# margin1       46
# margin2       85
# margin3       66
#             ...
# texture60    102
# texture61     53
# texture62    127
# texture63     65
# texture64     97
# Length: 194, dtype: int64

# %%
df_train.eq(0).sum()
# Out:
# id             0
# species        0
# margin1      203
# margin2      207
# margin3       23
#             ...
# texture60    763
# texture61    886
# texture62    348
# texture63    411
# texture64    204
# Length: 194, dtype: int64

# %%
df_train.describe()
# Out:
#                 id     margin1     margin2  ...   texture62   texture63   texture64
# count   990.000000  990.000000  990.000000  ...  990.000000  990.000000  990.000000
# mean    799.595960    0.017412    0.028539  ...    0.020291    0.008989    0.019420
# std     452.477568    0.019739    0.038855  ...    0.039040    0.013791    0.022768
# min       1.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     415.250000    0.001953    0.001953  ...    0.000000    0.000000    0.000977
# 50%     802.500000    0.009766    0.011719  ...    0.003906    0.002930    0.011719
# 75%    1195.500000    0.025391    0.041016  ...    0.023438    0.012695    0.029297
# max    1584.000000    0.087891    0.205080  ...    0.375980    0.086914    0.141600
#
# [8 rows x 193 columns]

# %%
df_test.shape
# Out:
# (594, 193)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Columns: 193 entries, id to texture64
# dtypes: float64(192), int64(1)
# memory usage: 895.8 KB

# %%
df_test.isna().sum()
# Out:
# id           0
# margin1      0
# margin2      0
# margin3      0
# margin4      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 193, dtype: int64

# %%
df_test.eq(0).sum()
# Out:
# id             0
# margin1      123
# margin2      132
# margin3       12
# margin4       52
#             ...
# texture60    446
# texture61    531
# texture62    211
# texture63    245
# texture64    122
# Length: 193, dtype: int64

# %%
df_test.describe()
# Out:
#                 id     margin1     margin2  ...   texture62   texture63   texture64
# count   594.000000  594.000000  594.000000  ...  594.000000  594.000000  594.000000
# mean    780.673401    0.017562    0.028425  ...    0.019975    0.009389    0.020970
# std     465.646977    0.019585    0.038351  ...    0.034704    0.013457    0.023407
# min       4.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     368.500000    0.001953    0.001953  ...    0.000000    0.000000    0.000977
# 50%     774.000000    0.009766    0.010743  ...    0.003418    0.002930    0.013184
# 75%    1184.500000    0.028809    0.041016  ...    0.022461    0.014648    0.032227
# max    1583.000000    0.085938    0.189450  ...    0.247070    0.086914    0.149410
#
# [8 rows x 193 columns]

# %% [markdown]
# # **Generate indices to split data into training and test set**

# %%
def encode(train, test):
    le = preprocessing.LabelEncoder().fit(train.species) 
    labels = le.transform(train.species)
    classes = list(le.classes_)
    test_ids = test.id
    
    train = train.drop(['species', 'id'], axis=1)  
    test = test.drop(['id'], axis=1)
    
    return train, labels, test, test_ids, classes

train, labels, test, test_ids, classes = encode(df_train, df_test)
train.head()
# Out:
#     margin1   margin2   margin3  ...  texture62  texture63  texture64
# 0  0.007812  0.023438  0.023438  ...   0.004883   0.000000   0.025391
# 1  0.005859  0.000000  0.031250  ...   0.000977   0.039062   0.022461
# 2  0.005859  0.009766  0.019531  ...   0.000000   0.020508   0.002930
# 3  0.000000  0.003906  0.023438  ...   0.017578   0.000000   0.047852
# 4  0.005859  0.003906  0.048828  ...   0.000000   0.000000   0.031250
#
# [5 rows x 192 columns]

# %%
sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=23)
#print(sss)
for train_index, test_index in sss.split(train, labels):
    #print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = train.values[train_index], train.values[test_index]
    y_train, y_test = labels[train_index], labels[test_index]

# %%
classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="rbf", C=0.025, probability=True),
    NuSVC(probability=True),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    GaussianNB()]

# %% [markdown]
# # **Logging for Visual Comparison**

# %%
log_cols=["Classifier", "Accuracy", "Log Loss"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    clf.fit(X_train, y_train)
    name = clf.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = clf.predict(X_test)
    acc = accuracy_score(y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
    train_predictions = clf.predict_proba(X_test)
    ll = log_loss(y_test, train_predictions)
    print("Log Loss: {}".format(ll))
    
    log_entry = pd.DataFrame([[name, acc*100, ll]], columns=log_cols)
    log = log.append(log_entry)
    
print("="*30)
# Out:
# ...
# KNeighborsClassifier
# ****Results****
# Accuracy: 86.3636%
# Log Loss: 2.7790716486578964
# ...
# SVC
# ****Results****
# Accuracy: 83.3333%
# Log Loss: 4.641428833385315
# ...
# NuSVC
# ****Results****
# Accuracy: 88.8889%
# Log Loss: 2.426764293218131
# ...
# DecisionTreeClassifier
# ****Results****
# Accuracy: 66.6667%
# Log Loss: 11.512925464970326
# ...
# RandomForestClassifier
# ****Results****
# Accuracy: 97.4747%
# Log Loss: 0.7871611437416219
# ...
# GaussianNB
# ****Results****
# Accuracy: 55.5556%
# Log Loss: 15.350567286627072
# ...

# %%
sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=log, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy')
plt.show()

sns.set_color_codes("muted")
sns.barplot(x='Log Loss', y='Classifier', data=log, color="g")

plt.xlabel('Log Loss')
plt.title('Classifier Log Loss')
plt.show()

# %% [markdown]
# **RandomForestClassifier has the best accuracy**

# %%
#Randomforest
#call
log_random = RandomForestClassifier()
#fit
log_random.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predict_test = log_random.predict(test)

# %%
print(predict_test)
# Out:
# [51 50  1 19 14  3  3 28 84  8 43 74 75 10 52 46 45 73 13 71 61 68 57 77
#   1 70 28 15 35 70 53 74 47 50  4 36 14 55 36 93  8 32  8  9 71 70 38 23
#  94 18 17  5 55 94 14 86 62 33 51 98 88 56 21 59 65 11 48  5 13  4 54 57
#  29  7 31 98 92 84 25 10 61 43 85 24  1  2 23 83 40 22 48 90 25 21 37 56
#  41 95  7 89 98 77  3 12 31 84 53 96 64 72 93 93 67 30  8 88 60 87  6 57
#  34 34 60 17 75 27 51 31 39 23 29  2 41 61 24 97 29 28 68 81 42 51 86 62
#  60 52 95 64 42 96 95 20 59 35 86  1 26 38 43 56 20 60 46 79 22 79 55 87
#  65 97 75 21 29 21 11 10 58 94 27 22 15 45 89 54 43  5 23 94 40 49 89 72
#  36 11 81 95 18 91 29 64 80  6 78 45 28  9 78 90 44 89 92 13  2 59  0 96
#  70 32 29 78 91 69 44 38  5 60 49 58 94 67 92 88 90 29 25 37 18  0 76 27
#  70 71 44 70 32 90 30 82 34 30 82 96 48 65 57 64 26 53 55 73  9  3 83 26
#  30 63 17 22 79 63 12 78 36 14 27 25 22 38 20 54 76 69 67 97 80 44 92 69
#  23 21 16 51 33 77 16 11 27  1 52 39 24 52 42 17  2 73 96 83 88  9 63 50
# ...
